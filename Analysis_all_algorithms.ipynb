# %%
import matplotlib.pyplot as plt
a = [84.24,84.41,84.88,84.79,85.04]
b = [80.43,80.03,79.77,80.4,80.37]
d = [80.85,81.22,81.4,81.45,81.69]
c = [10,20,30,40,50]
plt.plot(c,a,marker='o')
plt.plot(c,b,marker='^')
plt.plot(c,d)
plt.legend(['Ensemble','PCA','LDA'], )
plt.xlabel('Training Size')
plt.ylabel('Accuracies')
plt.title('Random Forest Accuracy Prediction using Feature Extraction/Selection')
plt.show()

# %%
# import matplotlib.pyplot as plt
# a = [46.15,50.34,52.31,54.54,55.65]
# b = [37.94,43.22,40.68,40.7,47.89]
# d = [49.92,51.1,54.06,55.73,57.45]
# c = [10,20,30,40,50]
# plt.plot(c,a,marker='o')
# plt.plot(c,b,marker='^')
# plt.plot(c,d)
# plt.legend(['Ensemble','PCA','LDA'], )
# plt.xlabel('Training Size')
# plt.ylabel('Accuracies')
# plt.title('Random Forest Accuracy Prediction using Feature Extraction/Selection')
# plt.show()

# %%
# import matplotlib.pyplot as plt
# a = [82.85,82.80,82.76,82.83,82.99]
# b = [84.30,84.34,84.51,84.53,84.79]
# c = [84.24,84.41,84.88,84.79,85.04]
# d = [85.63,85.83,85.86,86.04,86.16]
# e = [84.02,82.85,83.05,84.39,84.44]
# f = [84.28,83.82,84.12,84.17,84.07]
# g = [80.43,80.03,79.77,80.4,80.37]
# h = [80.85,81.22,81.4,81.45,81.69]
# i = [79.66,76.63,79.06,79.81,79.85]
# j = [80.68,81.12,81.42,81.45,81.67]

# t = [10,20,30,40,50]


# plt.plot(t,a,marker='o')
# plt.plot(t,b,marker='^')
# plt.plot(t,c,marker='*')
# plt.plot(t,d)
# plt.plot(t,e,marker='.')
# plt.plot(t,f,marker='+')
# plt.plot(t,g,marker='_')
# plt.plot(t,h,marker=9)
# plt.plot(t,i,marker=10)
# plt.plot(t,j,marker=11)


# plt.legend(['Voting','Bagging','RandomFor','Ada','GBoost','XGBoo','Svm_P','Svm_L','LR_P','LR_L'],loc=5)
# plt.xlabel('Training Size')
# plt.ylabel('Accuracies')
# plt.title('All models Comparison')

# plt.figure(figsize=(4,9))

# plt.show()

# %%
# import matplotlib.pyplot as plt
# a = [50.7,52.58,51.79,52.19,53]
# b = [45.88,49.42,50.27,54.06,55.0]
# c = [46.15,50.34,52.31,54.54,55.65]
# d = [50.1,50.65,51.35,54.03,56.43]
# e = [51.96,52.85,52.66,52,51.69]
# f = [52.05,52.43,52.40,51.95,51.57]
# g = [37.94,43.22,40.68,40.7,47.89]
# h = [49.92,51.1,54.06,55.73,57.45]
# i = [44.74,45.06,46.16,46.12,48.22]
# j = [50.64,52.48,52.22,52.56,53.04]

# t = [10,20,30,40,50]


# plt.plot(t,a,marker='o')
# plt.plot(t,b,marker='^')
# plt.plot(t,c,marker='*')
# plt.plot(t,d)
# plt.plot(t,e,marker='.')
# plt.plot(t,f,marker='+')
# plt.plot(t,g,marker='_')
# plt.plot(t,h,marker=9)
# plt.plot(t,i,marker=10)
# plt.plot(t,j,marker=11)


# plt.legend(['Voting','Bagging','RandomFor','Ada','GBoost','XGBoo','RF_P','RF_L','SVM_P','SVM_L'],loc=5)
# plt.xlabel('Training Size')
# plt.ylabel('Accuracies')
# plt.title('All models Comparison')

# plt.figure(figsize=(4,9))
# # plt.ylim(20,80)

# plt.show()

# %%
# import numpy as np
# import matplotlib.pyplot as plt
# import pandas as pd




# dataset = pd.read_csv('wine.csv',sep =";")
# x = dataset.iloc[:, [2,4,6]].values
# y = dataset.iloc[:, 11].values

# %%
# from sklearn.model_selection import train_test_split
# x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.5, random_state = 0)
# from sklearn.preprocessing import StandardScaler
# sc = StandardScaler()
# x_train = sc.fit_transform(x_train)
# x_test = sc.transform(x_test)


# # import xgboost as xgb
# # model=xgb.XGBClassifier(random_state=1,learning_rate=0.01)
# # model.fit(x_train, y_train)
# # model.score(x_test,y_test)

# from sklearn.ensemble import GradientBoostingClassifier
# model= GradientBoostingClassifier(learning_rate=0.01,random_state=1)
# model.fit(x_train, y_train)
# model.score(x_test,y_test)

# %%
import matplotlib.pyplot as plt
a = [76.46,76.5,75.94,76.06,76.03]
b = [77.82,77.65,77.8,77.86,77.89]
c = [75.93,75.89,75.94,76.06,76.03]
d = [80.37,80.4,80.48,80.62,80.75]
e = [84.02,82.85,83.05,84.39,84.44]


t = [10,20,30,40,50]


plt.plot(t,a,marker='o')
plt.plot(t,b,marker='^')
plt.plot(t,c,marker='*')
plt.plot(t,d)
plt.plot(t,e,marker='.')



plt.legend(['138','46810','1358','02591013','02'],loc=5)
plt.xlabel('Training Size')
plt.ylabel('Accuracies')
plt.title('Gradient Boosting')

plt.figure(figsize=(4,9))

plt.show()

# %%
# import matplotlib.pyplot as plt
# a = [45.27,45.85,46.74,47.09,46.34]
# b = [43.20,45.57,45.58,45.86,45.40]
# c = [44.56,46.46,46.98,46.73,46.59]
# e = [51.96,52.85,52.66,52,51.69]


# t = [10,20,30,40,50]


# plt.plot(t,a,marker='o')
# plt.plot(t,b,marker='^')
# plt.plot(t,c,marker='*')
# plt.plot(t,e,marker='.')



# plt.legend(['246','3589','0578','1710'],loc=5)
# plt.xlabel('Training Size')
# plt.ylabel('Accuracies')
# plt.title('Gradient Boosting')

# plt.figure(figsize=(4,9))

# plt.show()
